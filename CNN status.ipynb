# %%
import time

file = open("app.log", "r")


for line in file.readlines()[-20:]:
    print(line)

while 1:
    where = file.tell()
    line = file.readline()
    if not line:
        time.sleep(1)
        file.seek(where)
    else:
        print(line)
# Out:
# root - INFO - Saving model...
#
# root - INFO - Done.
#
# root - INFO - Epoch 2 Training loss: 2.052 Validation loss: 2.084
#
# root - INFO - Saving model...
#
# root - INFO - Done.
#
# root - INFO - Epoch 3 Training loss: 1.902 Validation loss: 1.968
#
# root - INFO - Saving model...
#
# root - INFO - Done.
#
# root - INFO - Epoch 4 Training loss: 1.745 Validation loss: 1.842
#
# root - INFO - Saving model...
#
# root - INFO - Done.
#
# root - INFO - Epoch 5 Training loss: 1.586 Validation loss: 1.710
#
# root - INFO - Saving model...
#
# root - INFO - Done.
#
# root - INFO - Epoch 6 Training loss: 1.428 Validation loss: 1.581
#
# root - INFO - Saving model...
#
# root - INFO - Done.
#
# root - INFO - Epoch 7 Training loss: 1.285 Validation loss: 1.466
#
# matplotlib.pyplot - DEBUG - Loaded backend module://ipykernel.pylab.backend_inline version unknown.
#
# root - INFO - CUDA NOT supported
#
# root - INFO - ####################
#
#  Training Model 0
#
# ...
